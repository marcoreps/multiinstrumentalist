# %%
import numpy as np
import matplotlib.pyplot as plt

# Array from .csv
arra=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-181549_3458A_3458B__parallel_INL.csv',delimiter=',',skip_header=1)

# Columns to lists
F5700A = [row[0] for row in arra]
HP3458A = [row[1] for row in arra]
HP3458B = [row[2] for row in arra]
PPMdeviationa = [(F5700A[x]-HP3458A[x])/(10/1000000) for x in range(len(HP3458A))]

figa, axa = plt.subplots()
#axa.plot(F5700A, PPMdeviationa, label='absolute')
axa.set_xlabel('Calibrator Vout')
axa.set_ylabel('PPM of 10V range')
axa.set_title("3458A INL test")
figa.set_size_inches(16, 9)
figa.patch.set_facecolor('white')


# Fit a polynomial function of degree 1
termsa = np.polyfit(F5700A, PPMdeviationa, 1)

# Create a function with the terms we just generated
polyfunctiona = np.poly1d(termsa)

bestfita = [PPMdeviationa[x]-polyfunctiona(F5700A[x]) for x in range(len(HP3458A))]

# Plot a little test
axa.plot(F5700A, bestfita, label='18:15')


#####################
arra=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-105659_3458A_INL.csv',delimiter=',',skip_header=1)
HP3458A = [row[1] for row in arra]
PPMdeviationa = [(F5700A[x]-HP3458A[x])/(10/1000000) for x in range(len(HP3458A))]
termsa = np.polyfit(F5700A, PPMdeviationa, 1)
polyfunctiona = np.poly1d(termsa)
bestfita = [PPMdeviationa[x]-polyfunctiona(F5700A[x]) for x in range(len(HP3458A))]
axa.plot(F5700A, bestfita, label='10:56')
#####################
arra=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-194426_3458A_3458B__parallel_INL.csv',delimiter=',',skip_header=1)
HP3458A = [row[1] for row in arra]
PPMdeviationa = [(F5700A[x]-HP3458A[x])/(10/1000000) for x in range(len(HP3458A))]
termsa = np.polyfit(F5700A, PPMdeviationa, 1)
polyfunctiona = np.poly1d(termsa)
bestfita = [PPMdeviationa[x]-polyfunctiona(F5700A[x]) for x in range(len(HP3458A))]
axa.plot(F5700A, bestfita, label='19:44')
#####################
arra=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-211725_3458A_3458B__parallel_INL.csv',delimiter=',',skip_header=1)
HP3458A = [row[1] for row in arra]
PPMdeviationa = [(F5700A[x]-HP3458A[x])/(10/1000000) for x in range(len(HP3458A))]
termsa = np.polyfit(F5700A, PPMdeviationa, 1)
polyfunctiona = np.poly1d(termsa)
bestfita = [PPMdeviationa[x]-polyfunctiona(F5700A[x]) for x in range(len(HP3458A))]
axa.plot(F5700A, bestfita, label='21:17')
#####################
arra=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-221404_3458A_3458B__parallel_INL.csv',delimiter=',',skip_header=1)
HP3458A = [row[1] for row in arra]
PPMdeviationa = [(F5700A[x]-HP3458A[x])/(10/1000000) for x in range(len(HP3458A))]
termsa = np.polyfit(F5700A, PPMdeviationa, 1)
polyfunctiona = np.poly1d(termsa)
bestfita = [PPMdeviationa[x]-polyfunctiona(F5700A[x]) for x in range(len(HP3458A))]
axa.plot(F5700A, bestfita, label='conversions during settle')
#####################
arra=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-225815_3458A_3458B__parallel_INL.csv',delimiter=',',skip_header=1)
HP3458A = [row[1] for row in arra]
PPMdeviationa = [(F5700A[x]-HP3458A[x])/(10/1000000) for x in range(len(HP3458A))]
termsa = np.polyfit(F5700A, PPMdeviationa, 1)
polyfunctiona = np.poly1d(termsa)
bestfita = [PPMdeviationa[x]-polyfunctiona(F5700A[x]) for x in range(len(HP3458A))]
axa.plot(F5700A, bestfita, label='TiNs settings')
#####################



axa.set_ylim([-0.21,0.21])
axa.legend()





PPMdeviationb = [(F5700A[x]-HP3458B[x])/(10/1000000) for x in range(len(HP3458B))]

figb, axb = plt.subplots()
#axb.plot(F5700A, PPMdeviationb, label='absolute')
axb.set_xlabel('Calibrator Vout')
axb.set_ylabel('PPM of 10V range')
axb.set_title("3458B INL test")
figb.set_size_inches(16, 9)
figb.patch.set_facecolor('white')

print("3458B best fit:")
# Fit a polynomial function of degree 1
termsb = np.polyfit(F5700A, PPMdeviationb, 1)

# Create a function with the terms we just generated
polyfunctionb = np.poly1d(termsb)

bestfitb = [PPMdeviationb[x]-polyfunctionb(F5700A[x]) for x in range(len(HP3458B))]

# Plot a little test
axb.plot(F5700A, bestfitb, label='18:15')


#####################
arrb=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-112122_3458B_INL.csv',delimiter=',',skip_header=1)
HP3458B = [row[1] for row in arrb]
PPMdeviationb = [(F5700A[x]-HP3458B[x])/(10/1000000) for x in range(len(HP3458B))]
termsb = np.polyfit(F5700A, PPMdeviationb, 1)
polyfunctionb = np.poly1d(termsb)
bestfitb = [PPMdeviationb[x]-polyfunctionb(F5700A[x]) for x in range(len(HP3458B))]
axb.plot(F5700A, bestfitb, label='10:56')
#####################
arrb=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-194426_3458A_3458B__parallel_INL.csv',delimiter=',',skip_header=1)
HP3458B = [row[2] for row in arrb]
PPMdeviationb = [(F5700A[x]-HP3458B[x])/(10/1000000) for x in range(len(HP3458B))]
termsb = np.polyfit(F5700A, PPMdeviationb, 1)
polyfunctionb = np.poly1d(termsb)
bestfitb = [PPMdeviationb[x]-polyfunctionb(F5700A[x]) for x in range(len(HP3458B))]
axb.plot(F5700A, bestfitb, label='19:44')
#####################
arrb=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-211725_3458A_3458B__parallel_INL.csv',delimiter=',',skip_header=1)
HP3458B = [row[2] for row in arrb]
PPMdeviationb = [(F5700A[x]-HP3458B[x])/(10/1000000) for x in range(len(HP3458B))]
termsb = np.polyfit(F5700A, PPMdeviationb, 1)
polyfunctionb = np.poly1d(termsb)
bestfitb = [PPMdeviationb[x]-polyfunctionb(F5700A[x]) for x in range(len(HP3458B))]
axb.plot(F5700A, bestfitb, label='21:17')
#####################
arrb=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-221404_3458A_3458B__parallel_INL.csv',delimiter=',',skip_header=1)
HP3458B = [row[2] for row in arrb]
PPMdeviationb = [(F5700A[x]-HP3458B[x])/(10/1000000) for x in range(len(HP3458B))]
termsb = np.polyfit(F5700A, PPMdeviationb, 1)
polyfunctionb = np.poly1d(termsb)
bestfitb = [PPMdeviationb[x]-polyfunctionb(F5700A[x]) for x in range(len(HP3458B))]
axb.plot(F5700A, bestfitb, label='conversions during settle')
#####################
arrb=np.genfromtxt('https://raw.githubusercontent.com/marcoreps/multiinstrumentalist/master/csv/20210920-225815_3458A_3458B__parallel_INL.csv',delimiter=',',skip_header=1)
HP3458B = [row[2] for row in arrb]
PPMdeviationb = [(F5700A[x]-HP3458B[x])/(10/1000000) for x in range(len(HP3458B))]
termsb = np.polyfit(F5700A, PPMdeviationb, 1)
polyfunctionb = np.poly1d(termsb)
bestfitb = [PPMdeviationb[x]-polyfunctionb(F5700A[x]) for x in range(len(HP3458B))]
axb.plot(F5700A, bestfitb, label='TiNs settings')
#####################

axb.set_ylim([-0.21,0.21])
axb.legend()





AvsB = [bestfita[x]-bestfitb[x] for x in range(len(HP3458B))]
figc, axc = plt.subplots()
#axb.plot(F5700A, PPMdeviationb, label='absolute')
axc.set_xlabel('Calibrator Vout')
axc.set_ylabel('bestfita[x]-bestfitb[x]')
axc.set_title("3458B INL test")
figc.set_size_inches(16, 9)
figc.patch.set_facecolor('white')
axc.plot(F5700A, AvsB, label='difference')
# Out:
# 3458B best fit:
